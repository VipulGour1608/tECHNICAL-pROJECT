# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [raw]
# MADHAV STORE DIWALI SALES DATA EDA

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %%
#IMPORTING THE LIBRARY::
import numpy as NP
import pandas as PD
import matplotlib.pyplot as PLT
import seaborn as SNS

# %%
DATA=PD.read_csv('Diwali Sales Data.csv', encoding= 'unicode_escape')
DATA
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11246     Maharashtra   Western         Chemical           Office       4
# 11247         Haryana  Northern       Healthcare       Veterinary       3
# 11248  Madhya Pradesh   Central          Textile           Office       4
# 11249       Karnataka  Southern      Agriculture           Office       3
# 11250     Maharashtra   Western       Healthcare           Office       3
#
#         Amount  Status  unnamed1  Unnamed: 15 Unnamed: 16
# 0      23952.0     NaN       NaN          NaN         NaN
# 1      23934.0     NaN       NaN          NaN         NaN
# 2      23924.0     NaN       NaN          NaN         NaN
# 3      23912.0     NaN       NaN          NaN         NaN
# 4      23877.0     NaN       NaN          NaN         NaN
# ...        ...     ...       ...          ...         ...
# 11246    370.0     NaN       NaN          NaN         NaN
# 11247    367.0     NaN       NaN          NaN         NaN
# 11248    213.0     NaN       NaN          NaN         NaN
# 11249    206.0     NaN       NaN          NaN         NaN
# 11250    188.0     NaN       NaN          NaN         NaN
#
# [11251 rows x 17 columns]

# %%
#SHAPE OF THE DATA::
DATA.shape
# Out:
# (11251, 17)

# %%
#UNDERSTANDING THE FIRST 5 ROWS::
DATA.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1  Unnamed: 15 Unnamed: 16
# 0  23952.0     NaN       NaN          NaN         NaN
# 1  23934.0     NaN       NaN          NaN         NaN
# 2  23924.0     NaN       NaN          NaN         NaN
# 3  23912.0     NaN       NaN          NaN         NaN
# 4  23877.0     NaN       NaN          NaN         NaN

# %%
#UNDERSTANDING THE LAST 5 ROWS::
DATA.tail()
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
#                 State      Zone   Occupation Product_Category  Orders  Amount  \
# 11246     Maharashtra   Western     Chemical           Office       4   370.0
# 11247         Haryana  Northern   Healthcare       Veterinary       3   367.0
# 11248  Madhya Pradesh   Central      Textile           Office       4   213.0
# 11249       Karnataka  Southern  Agriculture           Office       3   206.0
# 11250     Maharashtra   Western   Healthcare           Office       3   188.0
#
#        Status  unnamed1  Unnamed: 15 Unnamed: 16
# 11246     NaN       NaN          NaN         NaN
# 11247     NaN       NaN          NaN         NaN
# 11248     NaN       NaN          NaN         NaN
# 11249     NaN       NaN          NaN         NaN
# 11250     NaN       NaN          NaN         NaN

# %%
#INFORMATION ABOUT THE DATA::
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
#  15  Unnamed: 15       0 non-null      float64
#  16  Unnamed: 16       1 non-null      object
# dtypes: float64(4), int64(4), object(9)
# memory usage: 1.5+ MB

# %%
DATA.drop(["Status","unnamed1","Unnamed: 15","Unnamed: 16"],axis=1,inplace=True)

# %%
#SHAPE AFTER THE DROP UNRELATED COLUMNS::
DATA.shape
# Out:
# (11251, 13)

# %%
#INFORMATION ABOUT THE DATA,AFTER DROPPINGDA::
DATA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
#CHECKING FOR NULL VALUES::
DATA.isnull().sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
#DROP NULL VALUES::
DATA.dropna(inplace=True)

# %%
#AGAIN CHECKING FOR NULL VALUES::
DATA.isnull().sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
#checking data types for all columns::
DATA.dtypes
# Out:
# User_ID               int64
# Cust_name            object
# Product_ID           object
# Gender               object
# Age Group            object
# Age                   int64
# Marital_Status        int64
# State                object
# Zone                 object
# Occupation           object
# Product_Category     object
# Orders                int64
# Amount              float64
# dtype: object

# %%
DATA["Amount"]=DATA["Amount"].astype("int")

# %%
#CHECKING FOR DATA TYPES::
DATA.dtypes
# Out:
# User_ID              int64
# Cust_name           object
# Product_ID          object
# Gender              object
# Age Group           object
# Age                  int64
# Marital_Status       int64
# State               object
# Zone                object
# Occupation          object
# Product_Category    object
# Orders               int64
# Amount               int32
# dtype: object

# %%
#ALL COLUMNS::
DATA.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#RENAME THE COLUMN:
DATA.rename(columns={"Marital_Status":"Marital"})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28        0
# 1      1000732       Kartik  P00110942      F     26-35   35        1
# 2      1001990        Bindu  P00118542      F     26-35   35        1
# 3      1001425       Sudevi  P00237842      M      0-17   16        0
# 4      1000588         Joni  P00057942      M     26-35   28        1
# ...        ...          ...        ...    ...       ...  ...      ...
# 11246  1000695      Manning  P00296942      M     18-25   19        1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33        0
# 11248  1001209        Oshin  P00201342      F     36-45   40        0
# 11249  1004023       Noonan  P00059442      M     36-45   37        0
# 11250  1002744      Brumley  P00281742      F     18-25   19        0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# 1      Andhra Pradesh  Southern             Govt             Auto       3
# 2       Uttar Pradesh   Central       Automobile             Auto       3
# 3           Karnataka  Southern     Construction             Auto       2
# 4             Gujarat   Western  Food Processing             Auto       2
# ...               ...       ...              ...              ...     ...
# 11246     Maharashtra   Western         Chemical           Office       4
# 11247         Haryana  Northern       Healthcare       Veterinary       3
# 11248  Madhya Pradesh   Central          Textile           Office       4
# 11249       Karnataka  Southern      Agriculture           Office       3
# 11250     Maharashtra   Western       Healthcare           Office       3
#
#        Amount
# 0       23952
# 1       23934
# 2       23924
# 3       23912
# 4       23877
# ...       ...
# 11246     370
# 11247     367
# 11248     213
# 11249     206
# 11250     188
#
# [11239 rows x 13 columns]

# %%
#DESCRIBE THE DATA::
DATA.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
#DESCRIBE THE MAIN COLUMNS::
DATA[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
A=DATA_to_csv("DATA_CLEAN_MADHAV_STORE_SALES")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19588\1523469392.py in <module>
# ----> 1 A=DATA_to_csv("DATA_CLEAN_MADHAV_STORE_SALES")
#
# NameError: name 'DATA_to_csv' is not defined

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [raw]
# EXPLORATARY DATA ANALYSIS

# %% [markdown]
# # GENDER::

# %%
# plotting a bar chart for Gender and it's count

ax = SNS.countplot(x = 'Gender',data = DATA)
PLT.title("GENDER WISE COUNT OF PLOT")

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for gender vs total amount

sales_gen = DATA.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
ax=SNS.barplot(x = 'Gender',y= 'Amount' ,data = sales_gen)
PLT.title("GENDER VS AMOUNT")
# Out:
# Text(0.5, 1.0, 'GENDER VS AMOUNT')

# %% [raw]
# CONCLUSION::
# From above graphs we can see that most of the buyers are females and even the purchasing power of females are greater than men*

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [markdown]
# # AGE::

# %%
fig,ax=PLT.subplots(figsize=(10,5))
ax = SNS.countplot(data = DATA, x = 'Age Group', hue = 'Gender')
for bars in ax.containers:
    ax.bar_label(bars)
PLT.title("AGE-GROUP WISE GENDER COUNT")
# Out:
# Text(0.5, 1.0, 'AGE-GROUP WISE GENDER COUNT')

# %%
# Total Amount vs Age Group
fig,ax=PLT.subplots(figsize=(10,5))
sales_age = DATA.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
SNS.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
PLT.title("AGE-GROUP WISE AMOUNT SPEND")
# Out:
# Text(0.5, 1.0, 'AGE-GROUP WISE AMOUNT SPEND')

# %% [raw]
# CONCLUSION::
# From above graphs we can see that most of the buyers are of age group between 26-35 yrs female*

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [markdown]
# # STATE::

# %%
# total number of orders from top 10 states
fig,ax=PLT.subplots(figsize=(17,7))
sales_state = DATA.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)
ax=SNS.barplot(data = sales_state, x = 'State',y= 'Orders')
for bars in ax.containers:
    ax.bar_label(bars)
PLT.title("TOP 10 STATES IN TERMS OF ORDERS COUNT")
# Out:
# Text(0.5, 1.0, 'TOP 10 STATES IN TERMS OF ORDERS COUNT')

# %%
# total amount/sales from top 10 states
fig,ax=PLT.subplots(figsize=(17,7))
sales_state = DATA.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10) 
ax=SNS.barplot(data = sales_state, x = 'State',y= 'Amount')
PLT.title("TOP 10 STATES IN TERMS OF SALES")
# Out:
# Text(0.5, 1.0, 'TOP 10 STATES IN TERMS OF SALES')

# %% [raw]
# CONCLUSION::
# From above graphs we can see that most of the orders & total sales/amount are from Uttar Pradesh, Maharashtra and Karnataka respectively*

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [markdown]
# # Marital_Status

# %%
fig,ax=PLT.subplots(figsize=(8,5))
ax = SNS.countplot(data =DATA, x = 'Marital_Status')
for bars in ax.containers:
    ax.bar_label(bars)
PLT.title("MARITAL STATUS")
# Out:
# Text(0.5, 1.0, 'MARITAL STATUS')

# %%
fig,ax=PLT.subplots(figsize=(8,5))
sales_state = DATA.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
ax=SNS.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
PLT.title("MARITAL WISE AND GENDER WISE AMOUNT")
# Out:
# Text(0.5, 1.0, 'MARITAL WISE AND GENDER WISE AMOUNT')

# %% [raw]
# CONCLUSION::
# From above graphs we can see that most of the buyers are married (women) and they have high purchasing power.

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [markdown]
# # OCCUPATION::

# %%
#COUNT OF OCCUPATION::
fig,ax=PLT.subplots(figsize=(18,7))
ax = SNS.countplot(data =DATA, x = 'Occupation')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
fig,ax=PLT.subplots(figsize=(16,7))
sales_state = DATA.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
SNS.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='Amount'>

# %% [raw]
# CONCLUSION::
# From above graphs we can see that most of the buyers are working in IT, Healthcare and Aviation sector.

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [markdown]
# # PRODUCT CATEGORY

# %%
fig,ax=PLT.subplots(figsize=(20,5))
ax = SNS.countplot(data = DATA, x = 'Product_Category')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
fig,ax=PLT.subplots(figsize=(18,5))
sales_state = DATA.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)
SNS.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
PLT.title("TOP 10 PRODUCT WISE SALES")
# Out:
# Text(0.5, 1.0, 'TOP 10 PRODUCT WISE SALES')

# %% [raw]
# CONCLUSION::
# From above graphs we can see that most of the sold products are from Food, Clothing and Electronics category.

# %%
sales_state = DATA.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)
fig,ax=PLT.subplots(figsize=(18,5))
SNS.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
PLT.title("TOP 10 PRODUCT ID VS ORDERS")
# Out:
# Text(0.5, 1.0, 'TOP 10 PRODUCT ID VS ORDERS')

# %%
# top 10 most sold products (same thing as above)

fig,ax=PLT.subplots(figsize=(18,5))
DATA.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product_ID'>

# %% [raw]
# ================================================================================================================================================================================================================================================================

# %% [markdown]
# # CONCLUSION::
# Married women age group 26-35 yrs from UP,  Maharastra and Karnataka working in IT, Healthcare and Aviation are more likely to buy products from Food, Clothing and Electronics category*
